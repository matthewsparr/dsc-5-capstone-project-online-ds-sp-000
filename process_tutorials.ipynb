# %%
import nltk
from nltk import sent_tokenize
import string
import re
import ast
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Matthew\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
tutorials = open('tutorials.txt', 'r').read()

# %%
tutorials = tutorials.encode("utf-8").decode('unicode_escape')

# %%
tutorials
# Out:
# 'b\'[\\\'THREE MONKEYS ONE CAGE Solution\\n           OR\\n"How to construct a crude pulley system in public under life and death\\ncircumstances, while a mischievous ape tries repeatedly to pull your\\nshorts down"\\n\\nThis document contains complete spoilers for the game "Three Monkeys One\\nCage" by Robert Goodwin. It is inadvisable to be reading this if you\\nhaven\\\'t looked at the general in-game hints (type "HINT" during the\\ngame), and even then this document should be used sparingly. The game is\\nhard, but try to solve as much of it by yourself as you can, yeah?\\nYou\\\'ll feel better about yourself.\\n\\nThis solution is explained by sections.\\n\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n.\\n\\nTHE MANDRILL -- Keeping him out of your hair\\n\\nGenerally whenever the mandrill enters your corner of the cage or you\\nenter his, you have one turn to act before he does you in. Early on you\\ncan avoid death by simply moving to a differenct corner of the cage\\nw
# ...

# %%
tutorials = tutorials.replace('\n','').replace('\b','')
tutorials = " ".join(re.findall("[a-zA-Z_.]+", tutorials))

# %%
tutorials = tutorials.replace('\n','').replace('\b','')

# %%
tutorials
# Out:
# 'b\'[\\\'THREE MONKEYS ONE CAGE Solution\\\\n           OR\\\\n"How to construct a crude pulley system in public under life and death\\\\ncircumstances, while a mischievous ape tries repeatedly to pull your\\\\nshorts down"\\\\n\\\\nThis document contains complete spoilers for the game "Three Monkeys One\\\\nCage" by Robert Goodwin. It is inadvisable to be reading this if you\\\\nhaven\\\\\\\'t looked at the general in-game hints (type "HINT" during the\\\\ngame), and even then this document should be used sparingly. The game is\\\\nhard, but try to solve as much of it by yourself as you can, yeah?\\\\nYou\\\\\\\'ll feel better about yourself.\\\\n\\\\nThis solution is explained by sections.\\\\n\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n.\\\\n\\\\nTHE MANDRILL -- Keeping him out of your hair\\\\n\\\\nGenerally whenever the mandrill enters your corner of the cage or you\\\\nenter his, you have one turn to act before he does you in. Early on you
# ...

# %%
sentences = sent_tokenize(tutorials)

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokens = tokenizer.tokenize(tutorials)

# %%
tokens
# Out:
# ['b THREE MONKEYS ONE CAGE Solution n OR n How to construct a crude pulley system in public under life and death ncircumstances while a mischievous ape tries repeatedly to pull your nshorts down n nThis document contains complete spoilers for the game Three Monkeys One nCage by Robert Goodwin.',
#  'It is inadvisable to be reading this if you nhaven t looked at the general in game hints type HINT during the ngame and even then this document should be used sparingly.',
#  'The game is nhard but try to solve as much of it by yourself as you can yeah nYou ll feel better about yourself.',
#  'n nThis solution is explained by sections.',
#  'n n. n. n. n. n. n. n. n. n. n. n. n. n. n. n nTHE MANDRILL Keeping him out of your hair n nGenerally whenever the mandrill enters your corner of the cage or you nenter his you have one turn to act before he does you in.',
#  'Early on you ncan avoid death by simply moving to a differenct corner of the cage nwhenever he approaches.',
# ...
